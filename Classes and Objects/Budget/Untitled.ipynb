# %%
# %run 'FrequentExpenses.py'

# %%
# %run 'BudgetList.py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/workspace/BudgetList.py:52, in <module>
#      49   plt.show()
#      51 if __name__ == "__main__":
# ---> 52   main()
#
# File ~/workspace/BudgetList.py:41, in main()
#      39 for expense in expenses.list:
#      40   myBudgetList.append(expense.amount)
# ---> 41 print("The count of all expenses: "+ str(len(myBudgetList)))
#      42 for entry in myBudgetList:
#      43   print(entry)
#
# File ~/workspace/BudgetList.py:21, in BudgetList.__len__(self)
#      20 def __len__(self):
# ---> 21   return sum(self.expenses,self.overages)
#
# TypeError: can only concatenate list (not "float") to list

# %%
# %run 'BudgetList.py'
# Out:
# The count of all expenses: 37
# 115.75
# 28.6
# 27.97
# 621.17
# 300.0
# 6.87
# 14.63
# 6.18
# 15.96
# 25.17
# 16.49
# 13.77
# 2.08
# 2.52
# 50.35
# 488.96
# 260.37
# 27.18
# 300.0
# 34.22
# 25.75
# 44.81
# 102.85
# 10.26
# 9.71
# 11.73
# 1903.0
# 15.12
# 249.68
# 16.07
# 68.52
# 18.12
# 24.42
# 107.76
# 60.21
# 25.41
# 205.44
